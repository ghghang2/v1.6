# %%
import os
os.environ["GITHUB_TOKEN"] = "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"
os.environ["GHG_APP_PASSWORD"] = "ubrf alxe okqm sitc "
os.environ["LLAMACPP_API_KEY"] = "0000"

# %%
# !python run.py
# Out:
# [run] llama-server started (PID: 44735)
# Installing remaining dependencies...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libgtk-3-0 is already the newest version (3.24.33-1ubuntu2.2).
# 0 upgraded, 0 newly installed, 0 to remove and 164 not upgraded.
# Installing dependencies...
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-freefont-ttf is already the newest version (20120503-10build1).
# fonts-liberation is already the newest version (1:1.07.4-11).
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# xfonts-scalable is already the newest version (1:1.0.3-1.2ubuntu1).
# fonts-ipafont-gothic is already the newest version (00303-21ubuntu1).
# fonts-tlwg-loma-otf is already the newest version (1:0.7.3-1).
# fonts-unifont is already the newest version (1:14.0.01-1).
# fonts-wqy-zenhei is already the newest version (0.9.45-8).
# xfonts-cyrillic is already the newest version (1:1.0.5).
# fonts-noto-color-emoji is already the newest version (2.047-0ubuntu0.22.04.1).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1.2).
# libcairo2 is already the newest version (1.16.0-5ubuntu2.1).
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.21).
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.3).
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.4).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.9).
# libnspr4 is already the newest version (2:4.35-0ubuntu0.22.04.1).
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.4).
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 164 not upgraded.
# Waiting for llama-server health check...
#
# ============================================================
# ALL SERVICES RUNNING SUCCESSFULLY!
# WhatsApp QR: tail -f whatsapp_bridge.log
# ============================================================

# %%
# !nvidia-smi
# !fuser -v /dev/nvidia*
# !kill 9 7212
# Out:
# Tue Aug 18 18:16:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.03             Driver Version: 580.159.03     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L40S                    On  |   00000000:45:00.0 Off |                    0 |
# | N/A   68C    P0            262W /  262W |   36797MiB /  46068MiB |     86%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           44735      C   ./llama-server                        36786MiB |
# +-----------------------------------------------------------------------------------------+
# /bin/bash: line 1: fuser: command not found

# %%
from nbchat.ui import chatui
chatui.ChatUI()
# Out:
# HBox(children=(VBox(children=(HTML(value='<i>Loading...</i>', layout=Layout(border_bottom='1px solid #444', bo…
# <style>
#         .nbchat-history, .jp-OutputArea-output { background-color: #1a1a1a !important; }
#         .nbchat-sidebar { background-color: #1a1a1a !important; color: #e0e0e0 !important; }
#         .nbchat-sidebar * { color: #e0e0e0 !important; background-color: #1a1a1a !important; }
#         .nbchat-input-box textarea, .nbchat-history textarea { background-color: #2d2d2d !important; color: #e0e0e0 !important; }
#         .nbchat-history .jp-RenderedHTML { background-color: #1a1a1a !important; }
#         </style>

# %%
from nbchat.tools.push_to_github import push_to_github
push_to_github("l40s!")
# Out:
# Error lines received while fetching: error: failed to push some refs to 'https://github.com/ghghang2/v1.6.git'
# '{"status": "success", "repo": "ghghang2/v1.6"}'

# %%
# !gh release download --repo "ghghang2/llamacpp_l40s" --pattern llama-bench
# Out:
# 6m⣻

# %%
# !curl http://localhost:8889/metrics
# Out:
# # HELP llamacpp:prompt_tokens_total Number of prompt tokens processed, excluding cached tokens
# # TYPE llamacpp:prompt_tokens_total counter
# llamacpp:prompt_tokens_total 38871
# # HELP llamacpp:prompt_tokens_cached_total Number of prompt tokens reused from the cache
# # TYPE llamacpp:prompt_tokens_cached_total counter
# llamacpp:prompt_tokens_cached_total 380646
# # HELP llamacpp:prompt_seconds_total Total time spent processing prompts
# # TYPE llamacpp:prompt_seconds_total counter
# llamacpp:prompt_seconds_total 34.8429
# # HELP llamacpp:tokens_predicted_total Number of generation tokens processed
# # TYPE llamacpp:tokens_predicted_total counter
# llamacpp:tokens_predicted_total 35712
# # HELP llamacpp:tokens_predicted_seconds_total Total time spent generating tokens
# # TYPE llamacpp:tokens_predicted_seconds_total counter
# llamacpp:tokens_predicted_seconds_total 790.745
# # HELP llamacpp:n_decode_total Total number of llama_decode() calls, excluding speculative decoding and multimodal decoding
# # TYPE llamacpp:n_decode_total counter
# llamacpp:n_decode_total 16022
# # HELP llamacpp:n_tokens_max Largest observed sequence length (prompt + generation)
# # TYPE llamacpp:n_tokens_max counter
# llamacpp:n_tokens_max 42105
# # HELP llamacpp:spec_decode_num_draft_tokens_total Speculative: Total draft tokens generated
# # TYPE llamacpp:spec_decode_num_draft_tokens_total counter
# llamacpp:spec_decode_num_draft_tokens_total 46926
# # HELP llamacpp:spec_decode_num_accepted_tokens_total Speculative: Total draft tokens accepted by the target model
# # TYPE llamacpp:spec_decode_num_accepted_tokens_total counter
# llamacpp:spec_decode_num_accepted_tokens_total 20538
# # HELP llamacpp:spec_decode_num_drafts_total Speculative: Total speculative decoding verification steps
# # TYPE llamacpp:spec_decode_num_drafts_total counter
# llamacpp:spec_decode_num_drafts_total 15162
# # HELP llamacpp:prompt_tokens_seconds Average prompt throughput in tokens/s
# # TYPE llamacpp:prompt_tokens_seconds gauge
# llamacpp:prompt_tokens_seconds 0
# # HELP llamacpp:predicted_tokens_seconds Average generation throughput in tokens/s
# # TYPE llamacpp:predicted_tokens_seconds gauge
# llamacpp:predicted_tokens_seconds 0
# # HELP llamacpp:requests_processing Number of requests processing
# # TYPE llamacpp:requests_processing gauge
# llamacpp:requests_processing 1
# # HELP llamacpp:requests_deferred Number of requests deferred
# # TYPE llamacpp:requests_deferred gauge
# llamacpp:requests_deferred 0
# # HELP llamacpp:n_busy_slots_per_decode Average number of busy slots per llama_decode() call
# # TYPE llamacpp:n_busy_slots_per_decode gauge
# llamacpp:n_busy_slots_per_decode 1
# # HELP llamacpp:spec_decode_num_accepted_tokens_per_pos_total Accepted tokens per draft position
# # TYPE llamacpp:spec_decode_num_accepted_tokens_per_pos_total counter
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="0"} 9796
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="1"} 6403
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="2"} 4246
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="3"} 9
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="4"} 7
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="5"} 6
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="6"} 5
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="7"} 4
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="8"} 4
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="9"} 4
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="10"} 4
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="11"} 4
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="12"} 4
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="13"} 4
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="14"} 4
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="15"} 4
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="16"} 3
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="17"} 3
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="18"} 3
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="19"} 3
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="20"} 3
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="21"} 3
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="22"} 2
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="23"} 2
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="24"} 1
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="25"} 1
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="26"} 1
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="27"} 1
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="28"} 1
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="29"} 1
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="30"} 1
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="31"} 1
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="32"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="33"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="34"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="35"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="36"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="37"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="38"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="39"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="40"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="41"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="42"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="43"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="44"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="45"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="46"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="47"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="48"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="49"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="50"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="51"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="52"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="53"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="54"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="55"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="56"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="57"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="58"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="59"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="60"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="61"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="62"} 0
# llamacpp:spec_decode_num_accepted_tokens_per_pos_total{position="63"} 0
