# %%
import os
os.environ["GITHUB_TOKEN"] = "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"
os.environ["GHG_APP_PASSWORD"] = "ubrf alxe okqm sitc "
os.environ["LLAMACPP_API_KEY"] = "0000"

# %%
# !python run.py
# Out:
# [run] llama-server started (PID: 23301)
# Installing remaining dependencies...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# httpcore 1.0.5 requires h11<0.15,>=0.13, but you have h11 0.16.0 which is incompatible.
# /bin/sh: 1: sudo: not found
# Traceback (most recent call last):
#   File "/v1.6/run.py", line 286, in <module>
#     main()
#   File "/v1.6/run.py", line 234, in main
#     _run_blocking("sudo apt-get update -qq && sudo apt-get install -y libxcomposite1 libgtk-3-0 libatk1.0-0")
#   File "/v1.6/run.py", line 47, in _run_blocking
#     subprocess.run(cmd, shell=True, env=env, check=True)
#   File "/usr/lib/python3.11/subprocess.py", line 571, in run
#     raise CalledProcessError(retcode, process.args,
# ...

# %%
import os
GITHUB_TOKEN = "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"
# 1. Set your variables
FILES = ["llama-server"]
os.environ['GITHUB_TOKEN'] = GITHUB_TOKEN
REPO_NAME = "llamacpp_l40s"
USER_NAME = "ghghang2"
TAG = "v2.0"

# 2. Login to GitHub CLI
# !echo {GITHUB_TOKEN} > token.txt
# !gh auth login --with-token --hostname github.com < token.txt
# !rm token.txt

# 3. Create the repo if it doesn't exist, and initialize with a README
# This creates a 'main' branch so the repo is no longer 'empty'
print("Initializing repository...")
# !gh repo create {USER_NAME}/{REPO_NAME} --private || echo "Repo already exists"

# 4. Create the Release now that the repo has a commit history
print(f"Creating release {TAG}...")
# !gh release create {TAG} --title "T4 Binaries" --notes "Built for llama.cpp on G4 GPU" --repo {USER_NAME}/{REPO_NAME}

# 5. Upload your binaries
print("Uploading binaries...")
# !gh release upload {TAG} ../llama.cpp/build/bin/* --repo {USER_NAME}/{REPO_NAME} --clobber

print(f"\n✅ SUCCESS! Your binaries are at: https://github.com/{USER_NAME}/{REPO_NAME}/releases")
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.
# /bin/bash: line 1: token.txt: No space left on device
# /bin/bash: line 1: token.txt: No such file or directory
# rm: cannot remove 'token.txt': No such file or directory
# Initializing repository...
# GraphQL: Name already exists on this account (createRepository)
# Repo already exists
# Creating release v2.0...
# https://github.com/ghghang2/llamacpp_l40s/releases/tag/v2.0
# Uploading binaries...
# Successfully uploaded 94 assets to v2.0
#
# ✅ SUCCESS! Your binaries are at: https://github.com/ghghang2/llamacpp_l40s/releases

# %%
# !gh --help
# Out:
# Work seamlessly with GitHub from the command line.
#
# USAGE
#   gh <command> <subcommand> [flags]
#
# CORE COMMANDS
#   browse:     Open the repository in the browser
#   codespace:  Connect to and manage your codespaces
#   gist:       Manage gists
#   issue:      Manage issues
#   pr:         Manage pull requests
#   release:    Manage GitHub releases
#   repo:       Create, clone, fork, and view repositories
#
# ACTIONS COMMANDS
#   actions:    Learn about working with GitHub Actions
#   run:        View details about workflow runs
#   workflow:   View details about GitHub Actions workflows
#
# ADDITIONAL COMMANDS
#   alias:      Create command shortcuts
#   api:        Make an authenticated GitHub API request
#   auth:       Login, logout, and refresh your authentication
#   completion: Generate shell completion scripts
#   config:     Manage configuration for gh
#   extension:  Manage gh extensions
#   gpg-key:    Manage GPG keys
#   help:       Help about any command
# ...

# %%
# !nvidia-smi
# !fuser -v /dev/nvidia*
# !kill 9 7212
# Out:
# Tue Aug 18 19:19:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.03             Driver Version: 580.159.03     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L40S                    On  |   00000000:45:00.0 Off |                    0 |
# | N/A   46C    P0            108W /  262W |   35623MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
